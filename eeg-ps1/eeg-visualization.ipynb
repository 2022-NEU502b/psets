# %% [markdown]
# # EEG Problem Set: Visualization

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Visualize Raw Data
#
# **Load raw**

# %%
from mne.io import read_raw_fif

## Load raw data.
raw = read_raw_fif('sub-01_task-digitsymbol_raw.fif', verbose=False)
# Out:
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:425: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   ch_name = ch_name[:np.argmax(ch_name == b'')].tostring()
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\tag.py:346: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   return text_type(d.tostring().decode('latin1', 'ignore'))

# %% [markdown]
# **Visualize raw**

# %%
raw.plot(highpass=0.5, group_by='position');
# Out:
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\viz\raw.py:1245: MatplotlibDeprecationWarning:
# The set_window_title function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use manager.set_window_title or GUI-specific methods instead.
#   fig_selection.canvas.set_window_title('Selection')
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\viz\utils.py:1847: MatplotlibDeprecationWarning: The 'lineprops' parameter of __init__() has been renamed 'props' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   self.lasso = LassoSelector(ax, onselect=self.on_select,
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\pick.py:279: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pick = np.zeros(nchan, dtype=np.bool)
# C:\Users\jcian\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\viz\raw.py:868: MatplotlibDeprecationWarning:
# The set_window_title function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use manager.set_window_title or GUI-specific methods instead.
#   fig.canvas.set_window_title(title if title else "Raw")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1416/1187953122.py in <module>
# ----> 1 raw.plot(highpass=0.5, group_by='position');
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\base.py in plot(self, events, duration, start, n_channels, bgcolor, color, bad_color, event_color, scalings, remove_dc, order, show_options, title, show, block, highpass, lowpass, filtorder, clipping, show_first_samp, proj, group_by, butterfly, decim, noise_cov, event_id)
#    1868              show_first_samp=False, proj=True, group_by='type',
#    1869              butterfly=False, decim='auto', noise_cov=None, event_id=None):
# -> 1870         return plot_raw(self, events, duration, start, n_channels, bgcolor,
#    1871                         color, bad_color, event_color, scalings, remove_dc,
#    1872                         order, show_options, title, show, block, highpass,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\viz\raw.py in plot_raw(raw, events, duration, start, n_channels, bgcolor, color, bad_color, event_color, scalings, remove_dc, order, show_options, title, show, block, highpass, lowpass, filtorder, clipping, show_first_samp, proj, group_by, butterfly, decim, noise_cov, event_id)
#     400         fig_selection.canvas.mpl_connect('lasso_event', lasso_callback)
#     401
# --> 402     _prepare_mne_browse_raw(params, title, bgcolor, color, bad_color, inds,
#     403                             n_channels)
#     404
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\viz\raw.py in _prepare_mne_browse_raw(params, title, bgcolor, color, bad_color, inds, n_channels)
#     947     params['lines'] = [ax.plot([np.nan], antialiased=True, linewidth=0.5)[0]
#     948                        for _ in range(n_ch)]
# --> 949     ax.set_yticklabels(['X' * max([len(ch) for ch in info['ch_names']])])
#     950     params['fig_annotation'] = None
#     951     params['fig_help'] = None
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      73
#      74         def wrapper(self, *args, **kwargs):
# ---> 75             return get_method(self)(*args, **kwargs)
#      76
#      77         wrapper.__module__ = owner.__module__
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axis.py in _set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1796         if fontdict is not None:
#    1797             kwargs.update(fontdict)
# -> 1798         return self.set_ticklabels(labels, minor=minor, **kwargs)
#    1799
#    1800     def _set_tick_locations(self, ticks, *, minor=False):
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axis.py in set_ticklabels(self, ticklabels, minor, **kwargs)
#    1718             # remove all tick labels, so only error for > 0 ticklabels
#    1719             if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
# -> 1720                 raise ValueError(
#    1721                     "The number of FixedLocator locations"
#    1722                     f" ({len(locator.locs)}), usually from a call to"
#
# ValueError: The number of FixedLocator locations (20), usually from a call to set_ticks, does not match the number of ticklabels (1).

# %% [markdown]
# ## Visualize Preprocessed Data
#
# **Load preproc**

# %%
from mne.io import read_raw_fif

## Load raw data.
raw = read_raw_fif('sub-01_task-digitsymbol_preproc_raw.fif', verbose=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1416/4210371302.py in <module>
#       2
#       3 ## Load raw data.
# ----> 4 raw = read_raw_fif('sub-01_task-digitsymbol_preproc_raw.fif', verbose=False)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\fiff\raw.py in read_raw_fif(fname, allow_maxshield, preload, verbose)
#     454         preloading must be used.
#     455
# --> 456         .. versionchanged:: 0.18
#     457            Support for file-like objects.
#     458     allow_maxshield : bool | str (default False)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\fiff\raw.py in __init__(self, fname, allow_maxshield, preload, verbose)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\utils.py in verbose(function, *args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\fiff\raw.py in __init__(self, fname, allow_maxshield, preload, verbose)
#      84             raws.append(raw)
#      85             if next_fname is not None:
# ---> 86                 if not op.exists(next_fname):
#      87                     msg = (
#      88                         f'Split raw file detected but next file {next_fname} '
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\fiff\raw.py in _read_raw_file(self, fname, allow_maxshield, preload, do_check_fname, verbose)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\utils.py in verbose(function, *args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\fiff\raw.py in _read_raw_file(self, fname, allow_maxshield, preload, do_check_fname, verbose)
#     148             whole_file = preload if '.gz' in ext else False
#     149             del ext
# --> 150         else:
#     151             # file-like
#     152             if not preload:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\open.py in fiff_open(fname, preload, verbose)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\utils.py in verbose(function, *args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\open.py in fiff_open(fname, preload, verbose)
#     101 def fiff_open(fname, preload=False, verbose=None):
#     102     """Open a FIF file.
# --> 103
#     104     Parameters
#     105     ----------
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mne\io\open.py in _fiff_get_fid(fname)
#      27
#      28     def __exit__(self, type_, value, traceback):
# ---> 29         return
#      30
#      31     def close(self):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:\\classes\\502b\\psets\\eeg-ps1\\sub-01_task-digitsymbol_preproc_raw.fif'

# %% [markdown]
# **Visualize preproc**

# %%
# %matplotlib osx
raw.plot(group_by='position');
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1416/3165654777.py in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'osx')
#       2 raw.plot(group_by='position');
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2346                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2347             with self.builtin_trap:
# -> 2348                 result = fn(*args, **kwargs)
#    2349             return result
#    2350
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\magics\pylab.py in matplotlib(self, line)
#      97             print("Available matplotlib backends: %s" % backends_list)
#      98         else:
# ---> 99             gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100             self._show_matplotlib_backend(args.gui, backend)
#     101
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py in enable_matplotlib(self, gui)
#    3528                 gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
#    3529
# -> 3530         pt.activate_matplotlib(backend)
#    3531         configure_inline_support(self, backend)
#    3532
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py in activate_matplotlib(backend)
#     325     from matplotlib import pyplot as plt
#     326
# --> 327     plt.switch_backend(backend)
#     328
#     329     plt.show._needmain = False
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\pyplot.py in switch_backend(newbackend)
#     265     backend_name = cbook._backend_module_name(newbackend)
#     266
# --> 267     class backend_mod(matplotlib.backend_bases._Backend):
#     268         locals().update(vars(importlib.import_module(backend_name)))
#     269
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\pyplot.py in backend_mod()
#     266
#     267     class backend_mod(matplotlib.backend_bases._Backend):
# --> 268         locals().update(vars(importlib.import_module(backend_name)))
#     269
#     270     required_framework = _get_required_interactive_framework(backend_mod)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\backends\backend_macosx.py in <module>
#       2 from matplotlib import cbook
#       3 from matplotlib._pylab_helpers import Gcf
# ----> 4 from matplotlib.backends import _macosx
#       5 from matplotlib.backends.backend_agg import FigureCanvasAgg
#       6 from matplotlib.backend_bases import (
#
# ImportError: cannot import name '_macosx' from 'matplotlib.backends' (C:\Users\jcian\AppData\Roaming\Python\Python39\site-packages\matplotlib\backends\__init__.py)
